# %%
import pandas as pd
#Read in the data using pandas
df = pd.read_csv('Network_Intrusion_Dataset.csv')

# %%
df.head()
# Out:
#    Port_Number  Received_Packets  Received_Bytes  Sent_Bytes  Sent_Packets  \
# 0            4            305111        25506841   100234870        284579
# 1            2               209           20671     6316631           274
# 2            4               150           19774     6475473          3054
# 3            1              4699       100986365   124574097        413351
# 4            3               990          104058       88896           778
#
#    Port_Alive_Duration_Sec  Packets_Rx_Dropped  Packets_Tx_Dropped  \
# 0                     1657                   0                   0
# 1                       96                   0                   0
# 2                      166                   0                   0
# 3                     2267                   0                   0
# 4                      792                   0                   0
#
#    Packets_Rx_Errors  Packets_Tx_Errors  ...  Unknown_Load(Latest)  \
# 0                  0                  0  ...                     0
# 1                  0                  0  ...               6303353
# 2                  0                  0  ...               6439888
# 3                  0                  0  ...                     0
# 4                  0                  0  ...                  7152
#
#    Latest_Bytes_Counter  Is_Valid  Table_ID  Active_Flow_Entries  \
# 0                     0         1         0                    6
# 1                183877         1         0                    8
# 2                   502         1         0                    6
# 3                     0         1         0                    8
# 4                   715         1         0                    5
#
#    Packets_Looked_Up  Packets_Matched  Max_Size  Traffic_Type  \
# 0             992868           992744        -1        Normal
# 1              90551            90494        -1     Intrusion
# 2               7516             7418        -1     Intrusion
# 3             664849           664714        -1        Normal
# 4               4328             4201        -1     Intrusion
#
#    Intrusion_Traffic_Type
# 0                  Normal
# 1                PortScan
# 2                 TCP-SYN
# 3                  Normal
# 4               Blackhole
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (4998, 33)

# %%
df.describe()
# Out:
#        Port_Number  Received_Packets  Received_Bytes    Sent_Bytes  \
# count  4998.000000       4998.000000    4.998000e+03  4.998000e+03
# mean      2.235094      83932.478191    4.721429e+07  4.743702e+07
# std       1.062464     122394.118041    4.951127e+07  4.894604e+07
# min       1.000000         10.000000    8.560000e+02  5.775000e+03
# 25%       1.000000        836.500000    8.643970e+06  6.548716e+06
# 50%       2.000000       3595.500000    2.559362e+07  2.977196e+07
# 75%       3.000000     178957.750000    7.572793e+07  7.609763e+07
# max       4.000000     352772.000000    2.715916e+08  2.392430e+08
#
#         Sent_Packets  Port_Alive_Duration_Sec  Packets_Rx_Dropped  \
# count    4998.000000              4998.000000              4998.0
# mean   148407.440176              1377.489996                 0.0
# std    149713.797741               984.424260                 0.0
# min        42.000000                26.000000                 0.0
# 25%      1042.250000               241.000000                 0.0
# 50%    134206.500000              1385.000000                 0.0
# 75%    287707.500000              2237.000000                 0.0
# max    421598.000000              3317.000000                 0.0
#
#        Packets_Tx_Dropped  Packets_Rx_Errors  Packets_Tx_Errors  ...  \
# count              4998.0             4998.0             4998.0  ...
# mean                  0.0                0.0                0.0  ...
# std                   0.0                0.0                0.0  ...
# min                   0.0                0.0                0.0  ...
# 25%                   0.0                0.0                0.0  ...
# 50%                   0.0                0.0                0.0  ...
# 75%                   0.0                0.0                0.0  ...
# max                   0.0                0.0                0.0  ...
#
#        Total_Load(Latest)  Unknown_Load(Rate)  Unknown_Load(Latest)  \
# count        4.998000e+03        4.998000e+03          4.998000e+03
# mean         5.956710e+05        2.354032e+04          5.956710e+05
# std          1.950752e+06        1.224342e+05          1.950752e+06
# min          0.000000e+00       -6.303550e+05          0.000000e+00
# 25%          0.000000e+00        0.000000e+00          0.000000e+00
# 50%          0.000000e+00        0.000000e+00          0.000000e+00
# 75%          0.000000e+00        0.000000e+00          0.000000e+00
# max          1.891030e+07        1.746749e+06          1.891030e+07
#
#        Latest_Bytes_Counter  Is_Valid  Table_ID  Active_Flow_Entries  \
# count          4.998000e+03    4998.0    4998.0          4998.000000
# mean           2.354032e+04       1.0       0.0            54.488796
# std            1.224342e+05       0.0       0.0           617.386958
# min           -6.303550e+05       1.0       0.0             4.000000
# 25%            0.000000e+00       1.0       0.0             5.000000
# 50%            0.000000e+00       1.0       0.0             6.000000
# 75%            0.000000e+00       1.0       0.0             7.000000
# max            1.746749e+06       1.0       0.0          9987.000000
#
#        Packets_Looked_Up  Packets_Matched  Max_Size
# count       4.998000e+03     4.998000e+03    4998.0
# mean        4.113947e+05     4.112736e+05      -1.0
# std         3.889002e+05     3.888962e+05       0.0
# min         1.050000e+02     5.000000e+01      -1.0
# 25%         6.826250e+03     6.661750e+03      -1.0
# 50%         5.122400e+05     5.121590e+05      -1.0
# 75%         6.659060e+05     6.657710e+05      -1.0
# max         1.012574e+06     1.012439e+06      -1.0
#
# [8 rows x 31 columns]

# %%
list(df.columns)
# Out:
# ['Port_Number',
#  'Received_Packets',
#  'Received_Bytes',
#  'Sent_Bytes',
#  'Sent_Packets',
#  'Port_Alive_Duration_Sec',
#  'Packets_Rx_Dropped',
#  'Packets_Tx_Dropped',
#  'Packets_Rx_Errors',
#  'Packets_Tx_Errors',
#  'Delta_Received_Packets',
#  'Delta_Received_Bytes',
#  'Delta_Sent_Bytes',
#  'Delta_Sent_Packets',
#  'Delta_Port_Alive_Duration_Sec',
#  'Delta_Packets_Rx_Dropped',
#  'Delta_Packets_Tx_Dropped',
#  'Delta_Packets_Rx_Errors',
#  'Delta_Packets_Tx_Errors',
#  'Connection_Point',
#  'Total_Load(Rate)',
#  'Total_Load(Latest)',
#  'Unknown_Load(Rate)',
#  'Unknown_Load(Latest)',
#  'Latest_Bytes_Counter',
#  'Is_Valid',
#  'Table_ID',
#  'Active_Flow_Entries',
#  'Packets_Looked_Up',
#  'Packets_Matched',
#  'Max_Size',
#  'Traffic_Type',
#  'Intrusion_Traffic_Type']

# %%
import plotly.express as px
intrusion_traffic_type_fig = px.bar(df, x ='Intrusion_Traffic_Type', title ="Attacks Types")
traffic_type_fig = px.bar(df, x ='Traffic_Type', title ="Traffic Types")

# %%
intrusion_type_per_traffic_fig = px.bar(df,x= 'Traffic_Type',color='Intrusion_Traffic_Type',title='Attack types in Intrusion Traffic',
                                        color_discrete_sequence=px.colors.qualitative.Vivid)

# %%
traffic_type_fig.update_traces(dict(marker_line_width=0))
intrusion_traffic_type_fig.update_traces(dict(marker_line_width=0))
intrusion_type_per_traffic_fig.update_traces(dict(marker_line_width=0))

intrusion_traffic_type_fig.show()
traffic_type_fig.show()
intrusion_type_per_traffic_fig.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4998 entries, 0 to 4997
# Data columns (total 33 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Port_Number                    4998 non-null   int64
#  1   Received_Packets               4998 non-null   int64
#  2   Received_Bytes                 4998 non-null   int64
#  3   Sent_Bytes                     4998 non-null   int64
#  4   Sent_Packets                   4998 non-null   int64
#  5   Port_Alive_Duration_Sec        4998 non-null   int64
#  6   Packets_Rx_Dropped             4998 non-null   int64
#  7   Packets_Tx_Dropped             4998 non-null   int64
#  8   Packets_Rx_Errors              4998 non-null   int64
#  9   Packets_Tx_Errors              4998 non-null   int64
#  10  Delta_Received_Packets         4998 non-null   int64
#  11  Delta_Received_Bytes           4998 non-null   int64
#  12  Delta_Sent_Bytes               4998 non-null   int64
#  13  Delta_Sent_Packets             4998 non-null   int64
#  14  Delta_Port_Alive_Duration_Sec  4998 non-null   int64
#  15  Delta_Packets_Rx_Dropped       4998 non-null   int64
#  16  Delta_Packets_Tx_Dropped       4998 non-null   int64
#  17  Delta_Packets_Rx_Errors        4998 non-null   int64
#  18  Delta_Packets_Tx_Errors        4998 non-null   int64
#  19  Connection_Point               4998 non-null   int64
#  20  Total_Load(Rate)               4998 non-null   int64
#  21  Total_Load(Latest)             4998 non-null   int64
#  22  Unknown_Load(Rate)             4998 non-null   int64
#  23  Unknown_Load(Latest)           4998 non-null   int64
#  24  Latest_Bytes_Counter           4998 non-null   int64
#  25  Is_Valid                       4998 non-null   int64
#  26  Table_ID                       4998 non-null   int64
#  27  Active_Flow_Entries            4998 non-null   int64
#  28  Packets_Looked_Up              4998 non-null   int64
#  29  Packets_Matched                4998 non-null   int64
#  30  Max_Size                       4998 non-null   int64
#  31  Traffic_Type                   4998 non-null   object
#  32  Intrusion_Traffic_Type         4998 non-null   object
# dtypes: int64(31), object(2)
# memory usage: 1.3+ MB

# %%
df.describe().transpose()
# Out:
#                                 count          mean           std       min  \
# Port_Number                    4998.0  2.235094e+00  1.062464e+00       1.0
# Received_Packets               4998.0  8.393248e+04  1.223941e+05      10.0
# Received_Bytes                 4998.0  4.721429e+07  4.951127e+07     856.0
# Sent_Bytes                     4998.0  4.743702e+07  4.894604e+07    5775.0
# Sent_Packets                   4998.0  1.484074e+05  1.497138e+05      42.0
# Port_Alive_Duration_Sec        4998.0  1.377490e+03  9.844243e+02      26.0
# Packets_Rx_Dropped             4998.0  0.000000e+00  0.000000e+00       0.0
# Packets_Tx_Dropped             4998.0  0.000000e+00  0.000000e+00       0.0
# Packets_Rx_Errors              4998.0  0.000000e+00  0.000000e+00       0.0
# Packets_Tx_Errors              4998.0  0.000000e+00  0.000000e+00       0.0
# Delta_Received_Packets         4998.0  1.045504e+02  7.844713e+02       0.0
# Delta_Received_Bytes           4998.0  3.330881e+05  1.180140e+06       0.0
# Delta_Sent_Bytes               4998.0  3.118655e+05  1.154417e+06     278.0
# Delta_Sent_Packets             4998.0  9.554482e+01  7.658600e+02       2.0
# Delta_Port_Alive_Duration_Sec  4998.0  4.792517e+00  4.055450e-01       4.0
# Delta_Packets_Rx_Dropped       4998.0  0.000000e+00  0.000000e+00       0.0
# Delta_Packets_Tx_Dropped       4998.0  0.000000e+00  0.000000e+00       0.0
# Delta_Packets_Rx_Errors        4998.0  0.000000e+00  0.000000e+00       0.0
# Delta_Packets_Tx_Errors        4998.0  0.000000e+00  0.000000e+00       0.0
# Connection_Point               4998.0  2.462585e+00  1.141965e+00       1.0
# Total_Load(Rate)               4998.0  2.354032e+04  1.224342e+05 -630355.0
# Total_Load(Latest)             4998.0  5.956710e+05  1.950752e+06       0.0
# Unknown_Load(Rate)             4998.0  2.354032e+04  1.224342e+05 -630355.0
# Unknown_Load(Latest)           4998.0  5.956710e+05  1.950752e+06       0.0
# Latest_Bytes_Counter           4998.0  2.354032e+04  1.224342e+05 -630355.0
# Is_Valid                       4998.0  1.000000e+00  0.000000e+00       1.0
# Table_ID                       4998.0  0.000000e+00  0.000000e+00       0.0
# Active_Flow_Entries            4998.0  5.448880e+01  6.173870e+02       4.0
# Packets_Looked_Up              4998.0  4.113947e+05  3.889002e+05     105.0
# Packets_Matched                4998.0  4.112736e+05  3.888962e+05      50.0
# Max_Size                       4998.0 -1.000000e+00  0.000000e+00      -1.0
#
#                                       25%         50%          75%  \
# Port_Number                          1.00         2.0         3.00
# Received_Packets                   836.50      3595.5    178957.75
# Received_Bytes                 8643970.00  25593619.0  75727934.00
# Sent_Bytes                     6548716.25  29771955.0  76097629.00
# Sent_Packets                      1042.25    134206.5    287707.50
# Port_Alive_Duration_Sec            241.00      1385.0      2237.00
# Packets_Rx_Dropped                   0.00         0.0         0.00
# Packets_Tx_Dropped                   0.00         0.0         0.00
# Packets_Rx_Errors                    0.00         0.0         0.00
# Packets_Tx_Errors                    0.00         0.0         0.00
# Delta_Received_Packets               0.00         4.0         4.00
# Delta_Received_Bytes                 0.00       556.0       560.00
# Delta_Sent_Bytes                   280.00       556.0       560.00
# Delta_Sent_Packets                   2.00         4.0         4.00
# Delta_Port_Alive_Duration_Sec        5.00         5.0         5.00
# Delta_Packets_Rx_Dropped             0.00         0.0         0.00
# Delta_Packets_Tx_Dropped             0.00         0.0         0.00
# Delta_Packets_Rx_Errors              0.00         0.0         0.00
# Delta_Packets_Tx_Errors              0.00         0.0         0.00
# Connection_Point                     2.00         2.0         3.00
# Total_Load(Rate)                     0.00         0.0         0.00
# Total_Load(Latest)                   0.00         0.0         0.00
# Unknown_Load(Rate)                   0.00         0.0         0.00
# Unknown_Load(Latest)                 0.00         0.0         0.00
# Latest_Bytes_Counter                 0.00         0.0         0.00
# Is_Valid                             1.00         1.0         1.00
# Table_ID                             0.00         0.0         0.00
# Active_Flow_Entries                  5.00         6.0         7.00
# Packets_Looked_Up                 6826.25    512240.0    665906.00
# Packets_Matched                   6661.75    512159.0    665771.00
# Max_Size                            -1.00        -1.0        -1.00
#
#                                        max
# Port_Number                            4.0
# Received_Packets                  352772.0
# Received_Bytes                 271591638.0
# Sent_Bytes                     239242994.0
# Sent_Packets                      421598.0
# Port_Alive_Duration_Sec             3317.0
# Packets_Rx_Dropped                     0.0
# Packets_Tx_Dropped                     0.0
# Packets_Rx_Errors                      0.0
# Packets_Tx_Errors                      0.0
# Delta_Received_Packets             15659.0
# Delta_Received_Bytes             6302708.0
# Delta_Sent_Bytes                 6303182.0
# Delta_Sent_Packets                 15592.0
# Delta_Port_Alive_Duration_Sec          5.0
# Delta_Packets_Rx_Dropped               0.0
# Delta_Packets_Tx_Dropped               0.0
# Delta_Packets_Rx_Errors                0.0
# Delta_Packets_Tx_Errors                0.0
# Connection_Point                       5.0
# Total_Load(Rate)                 1746749.0
# Total_Load(Latest)              18910303.0
# Unknown_Load(Rate)               1746749.0
# Unknown_Load(Latest)            18910303.0
# Latest_Bytes_Counter             1746749.0
# Is_Valid                               1.0
# Table_ID                               0.0
# Active_Flow_Entries                 9987.0
# Packets_Looked_Up                1012574.0
# Packets_Matched                  1012439.0
# Max_Size                              -1.0

# %%
pd.set_option('display.float_format','{:.2f}'.format)

# %%
df.describe().transpose()
# Out:
#                                 count        mean         std        min  \
# Port_Number                   4998.00        2.24        1.06       1.00
# Received_Packets              4998.00    83932.48   122394.12      10.00
# Received_Bytes                4998.00 47214291.87 49511274.80     856.00
# Sent_Bytes                    4998.00 47437016.12 48946041.43    5775.00
# Sent_Packets                  4998.00   148407.44   149713.80      42.00
# Port_Alive_Duration_Sec       4998.00     1377.49      984.42      26.00
# Packets_Rx_Dropped            4998.00        0.00        0.00       0.00
# Packets_Tx_Dropped            4998.00        0.00        0.00       0.00
# Packets_Rx_Errors             4998.00        0.00        0.00       0.00
# Packets_Tx_Errors             4998.00        0.00        0.00       0.00
# Delta_Received_Packets        4998.00      104.55      784.47       0.00
# Delta_Received_Bytes          4998.00   333088.12  1180140.16       0.00
# Delta_Sent_Bytes              4998.00   311865.50  1154417.43     278.00
# Delta_Sent_Packets            4998.00       95.54      765.86       2.00
# Delta_Port_Alive_Duration_Sec 4998.00        4.79        0.41       4.00
# Delta_Packets_Rx_Dropped      4998.00        0.00        0.00       0.00
# Delta_Packets_Tx_Dropped      4998.00        0.00        0.00       0.00
# Delta_Packets_Rx_Errors       4998.00        0.00        0.00       0.00
# Delta_Packets_Tx_Errors       4998.00        0.00        0.00       0.00
# Connection_Point              4998.00        2.46        1.14       1.00
# Total_Load(Rate)              4998.00    23540.32   122434.25 -630355.00
# Total_Load(Latest)            4998.00   595670.96  1950752.07       0.00
# Unknown_Load(Rate)            4998.00    23540.32   122434.25 -630355.00
# Unknown_Load(Latest)          4998.00   595670.96  1950752.07       0.00
# Latest_Bytes_Counter          4998.00    23540.32   122434.25 -630355.00
# Is_Valid                      4998.00        1.00        0.00       1.00
# Table_ID                      4998.00        0.00        0.00       0.00
# Active_Flow_Entries           4998.00       54.49      617.39       4.00
# Packets_Looked_Up             4998.00   411394.66   388900.17     105.00
# Packets_Matched               4998.00   411273.58   388896.20      50.00
# Max_Size                      4998.00       -1.00        0.00      -1.00
#
#                                      25%         50%         75%          max
# Port_Number                         1.00        2.00        3.00         4.00
# Received_Packets                  836.50     3595.50   178957.75    352772.00
# Received_Bytes                8643970.00 25593619.00 75727934.00 271591638.00
# Sent_Bytes                    6548716.25 29771955.00 76097629.00 239242994.00
# Sent_Packets                     1042.25   134206.50   287707.50    421598.00
# Port_Alive_Duration_Sec           241.00     1385.00     2237.00      3317.00
# Packets_Rx_Dropped                  0.00        0.00        0.00         0.00
# Packets_Tx_Dropped                  0.00        0.00        0.00         0.00
# Packets_Rx_Errors                   0.00        0.00        0.00         0.00
# Packets_Tx_Errors                   0.00        0.00        0.00         0.00
# Delta_Received_Packets              0.00        4.00        4.00     15659.00
# Delta_Received_Bytes                0.00      556.00      560.00   6302708.00
# Delta_Sent_Bytes                  280.00      556.00      560.00   6303182.00
# Delta_Sent_Packets                  2.00        4.00        4.00     15592.00
# Delta_Port_Alive_Duration_Sec       5.00        5.00        5.00         5.00
# Delta_Packets_Rx_Dropped            0.00        0.00        0.00         0.00
# Delta_Packets_Tx_Dropped            0.00        0.00        0.00         0.00
# Delta_Packets_Rx_Errors             0.00        0.00        0.00         0.00
# Delta_Packets_Tx_Errors             0.00        0.00        0.00         0.00
# Connection_Point                    2.00        2.00        3.00         5.00
# Total_Load(Rate)                    0.00        0.00        0.00   1746749.00
# Total_Load(Latest)                  0.00        0.00        0.00  18910303.00
# Unknown_Load(Rate)                  0.00        0.00        0.00   1746749.00
# Unknown_Load(Latest)                0.00        0.00        0.00  18910303.00
# Latest_Bytes_Counter                0.00        0.00        0.00   1746749.00
# Is_Valid                            1.00        1.00        1.00         1.00
# Table_ID                            0.00        0.00        0.00         0.00
# Active_Flow_Entries                 5.00        6.00        7.00      9987.00
# Packets_Looked_Up                6826.25   512240.00   665906.00   1012574.00
# Packets_Matched                  6661.75   512159.00   665771.00   1012439.00
# Max_Size                           -1.00       -1.00       -1.00        -1.00

# %%
# df = df.drop(columns=df.loc[:, 'Packets_Rx_Dropped':'Packets_Tx_Errors'].columns)
# df = df.drop(columns=df.loc[:, 'Delta_Packets_Rx_Dropped':'Delta_Packets_Tx_Errors'].columns)

# Check if columns exist before dropping
columns_to_drop = ['ls_Valid', 'Table_ID', 'Max_Size']
existing_columns_to_drop = [col for col in columns_to_drop if col in df.columns]
df = df.drop(existing_columns_to_drop, axis=1)
df = df.drop('Is_Valid',axis=1)

df.describe(include="all").transpose()
# Out:
#                                 count unique     top  freq        mean  \
# Port_Number                   4998.00    NaN     NaN   NaN        2.24
# Received_Packets              4998.00    NaN     NaN   NaN    83932.48
# Received_Bytes                4998.00    NaN     NaN   NaN 47214291.87
# Sent_Bytes                    4998.00    NaN     NaN   NaN 47437016.12
# Sent_Packets                  4998.00    NaN     NaN   NaN   148407.44
# Port_Alive_Duration_Sec       4998.00    NaN     NaN   NaN     1377.49
# Delta_Received_Packets        4998.00    NaN     NaN   NaN      104.55
# Delta_Received_Bytes          4998.00    NaN     NaN   NaN   333088.12
# Delta_Sent_Bytes              4998.00    NaN     NaN   NaN   311865.50
# Delta_Sent_Packets            4998.00    NaN     NaN   NaN       95.54
# Delta_Port_Alive_Duration_Sec 4998.00    NaN     NaN   NaN        4.79
# Connection_Point              4998.00    NaN     NaN   NaN        2.46
# Total_Load(Rate)              4998.00    NaN     NaN   NaN    23540.32
# Total_Load(Latest)            4998.00    NaN     NaN   NaN   595670.96
# Unknown_Load(Rate)            4998.00    NaN     NaN   NaN    23540.32
# Unknown_Load(Latest)          4998.00    NaN     NaN   NaN   595670.96
# Latest_Bytes_Counter          4998.00    NaN     NaN   NaN    23540.32
# Active_Flow_Entries           4998.00    NaN     NaN   NaN       54.49
# Packets_Looked_Up             4998.00    NaN     NaN   NaN   411394.66
# Packets_Matched               4998.00    NaN     NaN   NaN   411273.58
# Traffic_Type                     4998      2  Normal  2641         NaN
# Intrusion_Traffic_Type           4998      6  Normal  2641         NaN
#
#                                       std        min        25%         50%  \
# Port_Number                          1.06       1.00       1.00        2.00
# Received_Packets                122394.12      10.00     836.50     3595.50
# Received_Bytes                49511274.80     856.00 8643970.00 25593619.00
# Sent_Bytes                    48946041.43    5775.00 6548716.25 29771955.00
# Sent_Packets                    149713.80      42.00    1042.25   134206.50
# Port_Alive_Duration_Sec            984.42      26.00     241.00     1385.00
# Delta_Received_Packets             784.47       0.00       0.00        4.00
# Delta_Received_Bytes           1180140.16       0.00       0.00      556.00
# Delta_Sent_Bytes               1154417.43     278.00     280.00      556.00
# Delta_Sent_Packets                 765.86       2.00       2.00        4.00
# Delta_Port_Alive_Duration_Sec        0.41       4.00       5.00        5.00
# Connection_Point                     1.14       1.00       2.00        2.00
# Total_Load(Rate)                122434.25 -630355.00       0.00        0.00
# Total_Load(Latest)             1950752.07       0.00       0.00        0.00
# Unknown_Load(Rate)              122434.25 -630355.00       0.00        0.00
# Unknown_Load(Latest)           1950752.07       0.00       0.00        0.00
# Latest_Bytes_Counter            122434.25 -630355.00       0.00        0.00
# Active_Flow_Entries                617.39       4.00       5.00        6.00
# Packets_Looked_Up               388900.17     105.00    6826.25   512240.00
# Packets_Matched                 388896.20      50.00    6661.75   512159.00
# Traffic_Type                          NaN        NaN        NaN         NaN
# Intrusion_Traffic_Type                NaN        NaN        NaN         NaN
#
#                                       75%          max
# Port_Number                          3.00         4.00
# Received_Packets                178957.75    352772.00
# Received_Bytes                75727934.00 271591638.00
# Sent_Bytes                    76097629.00 239242994.00
# Sent_Packets                    287707.50    421598.00
# Port_Alive_Duration_Sec           2237.00      3317.00
# Delta_Received_Packets               4.00     15659.00
# Delta_Received_Bytes               560.00   6302708.00
# Delta_Sent_Bytes                   560.00   6303182.00
# Delta_Sent_Packets                   4.00     15592.00
# Delta_Port_Alive_Duration_Sec        5.00         5.00
# Connection_Point                     3.00         5.00
# Total_Load(Rate)                     0.00   1746749.00
# Total_Load(Latest)                   0.00  18910303.00
# Unknown_Load(Rate)                   0.00   1746749.00
# Unknown_Load(Latest)                 0.00  18910303.00
# Latest_Bytes_Counter                 0.00   1746749.00
# Active_Flow_Entries                  7.00      9987.00
# Packets_Looked_Up               665906.00   1012574.00
# Packets_Matched                 665771.00   1012439.00
# Traffic_Type                          NaN          NaN
# Intrusion_Traffic_Type                NaN          NaN

# %%
df.isna().sum()/len(df)*100
# Out:
# Port_Number                     0.00
# Received_Packets                0.00
# Received_Bytes                  0.00
# Sent_Bytes                      0.00
# Sent_Packets                    0.00
# Port_Alive_Duration_Sec         0.00
# Delta_Received_Packets          0.00
# Delta_Received_Bytes            0.00
# Delta_Sent_Bytes                0.00
# Delta_Sent_Packets              0.00
# Delta_Port_Alive_Duration_Sec   0.00
# Connection_Point                0.00
# Total_Load(Rate)                0.00
# Total_Load(Latest)              0.00
# Unknown_Load(Rate)              0.00
# Unknown_Load(Latest)            0.00
# Latest_Bytes_Counter            0.00
# Active_Flow_Entries             0.00
# Packets_Looked_Up               0.00
# Packets_Matched                 0.00
# Traffic_Type                    0.00
# Intrusion_Traffic_Type          0.00
# dtype: float64

# %%
df.to_csv('prepared_Network_Intrusion_Dataset.csv',index=False)

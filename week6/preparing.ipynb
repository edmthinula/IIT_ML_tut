# %%
from sklearn import preprocessing,tree,metrics
from sklearn.model_selection import train_test_split,GridSearchCV
from matplotlib import pyplot as plt
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,ConfusionMatrixDisplay,RocCurveDisplay
import pandas as pd 
import numpy as np 
import plotly.express as px

# %%
df = pd.read_csv('prepared_loan_approval_data.csv')

# %%
df.drop('max_allowed_loan',axis=1, inplace=True)
df.head()
# Out:
#       id   age  income  home_ownership  emplyment_length  loan_intent  \
# 0  19180  40.0  182004               3                 3            1
# 1  28072  40.0   90000               0                 3            2
# 2  32074  40.0  131004               0                 9            5
# 3   7224  40.0  150000               0                 9            0
# 4  14471  40.0  132000               0                 3            2
#
#    loan_amount  loan_interest_rate  loan_income_ratio  \
# 0        35000                8.00               0.19
# 1        35000               12.42               0.39
# 2        30000                7.90               0.23
# 3        25000               11.89               0.17
# 4        25000               16.82               0.22
#
#    payment_default_on_file  credit_history_length  loan_approval_status
# 0                        0                     11                     0
# 1                        0                     14                     0
# ...

# %%
df.to_csv(r'loan_approval_status_data.csv', index=False)

# %%
df2=pd.read_csv('prepared_loan_approval_data.csv')

# %%
approved_loan_applicants =  df2[(df2.loan_approval_status < 1)]

# %%
approved_loan_applicants.describe().transpose()
# Out:
#                            count          mean           std      min  \
# id                       50288.0  29377.309656  16930.537548     0.00
# age                      50288.0     27.552652      5.964567    20.00
# income                   50288.0  66675.948178  39309.701733  4200.00
# home_ownership           50288.0      1.543251      1.456797     0.00
# emplyment_length         50288.0      4.860802      3.913256     0.00
# loan_intent              50288.0      2.553571      1.730527     0.00
# loan_amount              50288.0   8888.048481   5326.987911   500.00
# loan_interest_rate       50288.0     10.258690      2.826840     5.42
# loan_income_ratio        50288.0      0.145101      0.077866     0.00
# payment_default_on_file  50288.0      0.121401      0.326839     0.00
# credit_history_length    50288.0      5.818883      4.002103     2.00
# loan_approval_status     50288.0      0.000000      0.000000     0.00
# ...

# %%
approved_loan_applicants.drop('loan_approval_status',axis=1, inplace=True)
approved_loan_applicants.head()
# Out:
# C:\Users\thinu\AppData\Local\Temp\ipykernel_23212\2311590638.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loan_applicants.drop('loan_approval_status',axis=1, inplace=True)
#       id   age  income  home_ownership  emplyment_length  loan_intent  \
# 0  19180  40.0  182004               3                 3            1
# 1  28072  40.0   90000               0                 3            2
# 2  32074  40.0  131004               0                 9            5
# 3   7224  40.0  150000               0                 9            0
# 4  14471  40.0  132000               0                 3            2
#
#    loan_amount  loan_interest_rate  loan_income_ratio  \
# 0        35000                8.00               0.19
# 1        35000               12.42               0.39
# ...

# %%
approved_loan_applicants.to_csv(r'loan_max_amount_data.csv', index=False)

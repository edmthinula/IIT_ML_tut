# %%
import matplotlib.pyplot  as plt
import numpy as np
import pandas as pd

# %%
xpoints = np.array([0, 6])

ypoints = np.array([0, 250])

# %%
plt.plot(xpoints, ypoints)
plt.show()

# %%
ypoints = np.array([4, 3, 8, 10])
plt.plot(ypoints, marker = 'o')
plt.show()

# %%
x = np.array([80, 95, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.title("Sports Watch Data")

plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.title("Sports Watch Data")
plt.grid()

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
x = ["APPLES", "BANANAS"]
y = [400, 350]
plt.bar(x, y)
# Out:
# <BarContainer object of 2 artists>

# %%
x = [-1, 0, 2, 5, 8, 23, 43, 12, 17]
y = [10, 15, 20, 25, 30, 35, 40, 45, 50]
plt.plot(x, y, label="Li-TPA Penetration Depth", color="blue", linewidth=2)
plt.xlabel("Distance [µm]")  # Label for X-axis
plt.ylabel("Penetration Depth")  # Label for Y-axis
plt.title("Penetration Depth Profile of Li-TPA")  # Graph title
plt.legend()  # Show legend
plt.grid(True)  # Enable grid for better visualization
plt.show()
